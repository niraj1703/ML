# %% [markdown]
# # XGBoost Classifier with Early Stopping
# This notebook demonstrates using XGBClassifier on the Iris dataset with early stopping and feature importance.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier, plot_importance
import matplotlib.pyplot as plt

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\dhira\anaconda3\python.exe

# %%
# Train XGBClassifier with early stopping
model = XGB
model = XGBClassifier(n_estimators=100, eval_metric='mlogloss')
model.fit(
    X_train, y_train,
    eval_set=[(X_test, y_test)],
    early_stopping_rounds=10,
    verbose=False
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Train XGBClassifier with early stopping
# ----> 2 model = XGB
#       3 model = XGBClassifier(n_estimators=100, eval_metric='mlogloss')
#       4 model.fit(
#       5     X_train, y_train,
#       6     eval_set=[(X_test, y_test)],
#       7     early_stopping_rounds=10,
#       8     verbose=False
#       9 )
#
# NameError: name 'XGB' is not defined

# %%
# Predict and evaluate
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Predict and evaluate
# ----> 2 y_pred = model.predict(X_test)
#       3 accuracy = accuracy_score(y_test, y_pred)
#       4 print(f"Accuracy: {accuracy:.2f}")
#
# File ~\anaconda3\Lib\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File ~\anaconda3\Lib\site-packages\xgboost\sklearn.py:1718, in XGBClassifier.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1707 @_deprecate_positional_args
#    1708 def predict(
#    1709     self,
#    (...)   1715     iteration_range: Optional[IterationRange] = None,
#    1716 ) -> ArrayLike:
#    1717     with config_context(verbosity=self.verbosity):
# ...

# %%
# Plot feature importance
plot_importance(model)
plt.show()

# %%
import pandas as pd
df = pd.DataFrame({
    "Fruit": ["Apple", "Banana", "Orange"],
    "Count": [10, 20, 15]
})
fig = px.bar(df, x="Fruit", y="Count", title="Fruits Count")
fig.show()

# %%
df = px.data.tips()
fig = px.bar(df, x="day", y="total_bill", color="sex", barmode="group")
fig.show()

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(rows=1, cols=2)
fig.add_trace(go.Scatter(y=[1, 2, 3]), row=1, col=1)
fig.add_trace(go.Bar(y=[4, 5, 6]), row=1, col=2)
fig.show()

# %%
df = px.data.stocks()
fig = px.line(df, x="date", y=["GOOG", "AAPL", "AMZN"], title="Stock Prices")
fig.show()

# %%
df = px.data.gapminder().query("year==2007")
fig = px.choropleth(df, locations="iso_alpha", color="lifeExp",
                    hover_name="country", color_continuous_scale=px.colors.sequential.Plasma)
fig.show()

# %%
df = px.data.iris()
fig = px.scatter_3d(df, x="sepal_length", y="sepal_width", z="petal_length", color="species")
fig.show()

# %%
df = px.data.gapminder()
fig = px.scatter(df, x="gdpPercap", y="lifeExp", animation_frame="year",
                 size="pop", color="continent", hover_name="country", log_x=True)
fig.show()

# %%
import dash 
from dash import dcc, html

app = dash.Dash(__name__)

app.layout = html.Div([
    html.H1("Simple Dash App"),
    dcc.Graph(figure=px.bar(x=["A", "B", "C"], y=[3, 1, 2]))
])

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import dash
#       2 from dash import dcc, html
#       4 app = dash.Dash(__name__)
#
# ModuleNotFoundError: No module named 'dash'

# %%
df_melted = df.melt(id_vars="Product", var_name="Month", value_name="Sales")

fig = px.bar(
    df_melted,
    x="Month",
    y="Sales",
    color="Product",
    barmode="group",
    title="Grouped Bar Chart: Monthly Sales per Product"
)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df_melted = df.melt(id_vars="Product", var_name="Month", value_name="Sales")
#       3 fig = px.bar(
#       4     df_melted,
#       5     x="Month",
#    (...)      9     title="Grouped Bar Chart: Monthly Sales per Product"
#      10 )
#      11 fig.show()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:9942, in DataFrame.melt(self, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#    9932 @Appender(_shared_docs["melt"] % {"caller": "df.melt(", "other": "melt"})
#    9933 def melt(
#    9934     self,
#    (...)   9940     ignore_index: bool = True,
#    9941 ) -> DataFrame:
# -> 9942     return melt(
#    9943         self,
#    9944         id_vars=id_vars,
#    9945         value_vars=value_vars,
#    9946         var_name=var_name,
# ...

# %%
df = px.data.gapminder()

fig = px.scatter(
    df,
    x="gdpPercap",
    y="lifeExp",
    animation_frame="year",
    animation_group="country",
    size="pop",
    color="continent",
    hover_name="country",
    log_x=True,
    size_max=60,
    title="GDP vs Life Expectancy Over Time",
    labels={"gdpPercap": "GDP per Capita", "lifeExp": "Life Expectancy"}
)
fig.show()

# %%
import plotly.express as px

days = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
temp = [30, 32, 31, 29, 28, 27, 26]

fig = px.line(x=days, y=temp, title="Weekly Temperature Trend", labels={'x':'Day', 'y':'Temperature (°C)'})
fig.show()

# %%
products = ["Laptop", "Mobile", "Tablet"]
sales = [250, 400, 150]

fig = px.bar(x=products, y=sales, title="Product Sales", labels={'x':'Product', 'y':'Sales'})
fig.show()

# %%
brands = ["Brand A", "Brand B", "Brand C"]
shares = [45, 30, 25]

fig = px.pie(names=brands, values=shares, title="Market Share")
fig.show()

# %%
import plotly.express as px
df = px.data.tips()

fig = px.bar(df, x="day", y="total_bill", color="sex", barmode="group", title="Sales by Gender per Day")
fig.show()

# %%
fig.update_layout(
    title="Customized Chart",
    xaxis_title="Custom X",
    yaxis_title="Custom Y",
    plot_bgcolor='lightblue',
    paper_bgcolor='lightgray'
)

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

fig = make_subplots(rows=1, cols=2, subplot_titles=("Line", "Bar"))

fig.add_trace(go.Scatter(x=[1,2,3], y=[4,5,6], name="Line"), row=1, col=1)
fig.add_trace(go.Bar(x=["A", "B", "C"], y=[2, 3, 1], name="Bar"), row=1, col=2)

fig.update_layout(title="Line and Bar Subplots")
fig.show()

# %%
df = px.data.stocks()
fig = px.line(df, x="date", y=["GOOG", "AAPL", "AMZN"], title="Stock Prices Over Time")
fig.show()

# %%
df = px.data.iris()
fig = px.scatter_3d(df, x="sepal_length", y="sepal_width", z="petal_length", color="species")
fig.show()

# %%
df = px.data.gapminder().query("year==2007")
fig = px.choropleth(df, locations="iso_alpha", color="lifeExp", hover_name="country", title="World Life Expectancy")
fig.show()

# %%
df = px.data.gapminder()
fig = px.scatter(df, x="gdpPercap", y="lifeExp", animation_frame="year", animation_group="country",
                 size="pop", color="continent", log_x=True, hover_name="country", title="Animated GDP vs Life Expectancy")
fig.show()

# %% [markdown]
# Logistic Regression
#
# $$
# \hat{y} = \frac{1}{1 + e^{-z}}
# $$
#
# $$
# Z = w \cdot X + b
# $$
#
#
# $\hat{y}$ → predicted value
#
# $X$ → Independent Variable
#
# $w$ → weight
#
# $b$ → bias
#
# __Gradient Descent__
#
# Gradient Descent is an optimized Algorithms used for minimizing the loss function in various machine learning algorithms .
# it is used for updating the parameters of the learning model
#
# $w = w - \alpha \cdot dw$
# $b = b - \alpha \cdot db$
#
# **Learning Rate:**
# Learning rate ($\alpha$) is a tuning parameter in an optimization algorithm that determines the step size at each iteration while moving toward a minimum of a loss function.
#
# **Derivatives:**
#
# $$
# dw = \frac{1}{m} \cdot (\hat{Y} - Y) \cdot X
# $$
#
# $$
# db = \frac{1}{m} \cdot (\hat{Y} - Y)
# $$
#
#
# Import & Prepare Data (we’ll make a small dataset for example)
#
# Sigmoid Function – converts any number to a probability between 0 and 1
#
# Cost Function – measures prediction error (Log Loss)
#
# Gradient Descent – updates weights & bias
#
# Training Loop – repeat until convergence
#
# Prediction – classify as 0 or 1

# %%
import numpy as np

# %%
class Linear_Regression():
   # declaring learning rate & number of iterations (Hyperparameter)
    def __init__(self, learning_rate, no_of_iterations):
        self.learning_rate = learning_rate
        self.no_of_iterations = no_of_iterations
   
   # first function to train the model with dataset
    def fit(self, x, y):
   # number of data points in the dataset (number of rows)--> m 
   # number of input feartures in the dataset (number)--> n
        self.m, self.n = x.shape
   # Initialize weights & bias value
        self.w = np.zeros(self.n)
        self.b = 0
        self.x = x
        self.y = y

   # Gradient Descent
        for _ in range(self.no_of_iterations):
            self.update_weights( )


    def update_weights(self):

        # y_ht formula (sigmoid function)
        y_hat = 1/(1 + np.exp(-(self.x.dot(self.w)+ self.b)))

        # Derivaties
          dw = (1/(self.m)*np.dot(self.X.T, (y_hat - self.y))
          db = (1/(self.m)*np.sum(y_hat - self.y)


        # Update weights and bias
        self.w =    self.w - self.learning_rate * dw
        self.b =    self.b - self.learning_rate * db
                  
        # sigmoid equation & decision boundary
    def predict(self):
                y_pred = 1/(1+np.exp(-(self.X.dot(self.w)* self.b) ))
                y_pred = np.where(y_pred > 0.5, 1, 0) 
       return y_pred
# Out:
#   Cell In[21], line 29
#     dw = (1/(self.m)*np.dot(self.X.T, (y_hat - self.y))
#     ^
# IndentationError: unexpected indent

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\dhira\data.csv")

# %%
df
# Out:
#         ID  Gender
# 0        1    Male
# 1        2     NaN
# 2        3  Female
# 3        4  Female
# 4        5    Male
# ...    ...     ...
# 4995  4996   Other
# 4996  4997    Male
# 4997  4998    Male
# 4998  4999   Other
# 4999  5000  Female
#
# [5000 rows x 2 columns]

# %%
df.columns = df.columns.str.strip()  # remove leading/trailing spaces

# %%
df
# Out:
#         ID  Gender
# 0        1    Male
# 1        2     NaN
# 2        3  Female
# 3        4  Female
# 4        5    Male
# ...    ...     ...
# 4995  4996   Other
# 4996  4997    Male
# 4997  4998    Male
# 4998  4999   Other
# 4999  5000  Female
#
# [5000 rows x 2 columns]

# %%
if "ID" in df.columns:
    df.drop(columns=["ID"], inplace=True)

# %%
df
# Out:
#       Gender
# 0       Male
# 1        NaN
# 2     Female
# 3     Female
# 4       Male
# ...      ...
# 4995   Other
# 4996    Male
# 4997    Male
# 4998   Other
# 4999  Female
#
# [5000 rows x 1 columns]

# %%
df.drop(columns=["ID"], inplace=True, errors='ignore')

# %%
df
# Out:
#       Gender
# 0       Male
# 1        NaN
# 2     Female
# 3     Female
# 4       Male
# ...      ...
# 4995   Other
# 4996    Male
# 4997    Male
# 4998   Other
# 4999  Female
#
# [5000 rows x 1 columns]

# %%
if "ID" in df.columns:
    del df["ID"]

# %%
df
# Out:
#       Gender
# 0       Male
# 1        NaN
# 2     Female
# 3     Female
# 4       Male
# ...      ...
# 4995   Other
# 4996    Male
# 4997    Male
# 4998   Other
# 4999  Female
#
# [5000 rows x 1 columns]

# %%
df['Temperature'] = np.random.randint(20, 40, size=len(df))
df['Day'] = np.random.choice(['Sunday', 'Monday', 'Tuesday', 'Wednesday','Thrusday','Friday','Saturday',], size=len(df))

# %%
df
# Out:
#       Gender       Day  Temperature
# 0       Male   Tuesday           21
# 1        NaN   Tuesday           26
# 2     Female  Thrusday           39
# 3     Female  Saturday           25
# 4       Male  Thrusday           30
# ...      ...       ...          ...
# 4995   Other    Sunday           22
# 4996    Male  Saturday           26
# 4997    Male    Monday           23
# 4998   Other    Sunday           30
# 4999  Female   Tuesday           20
#
# [5000 rows x 3 columns]

# %%
if "Gender" in df.columns:
    del df["Gender"]

# %%
df
# Out:
#            Day  Temperature
# 0      Tuesday           21
# 1      Tuesday           26
# 2     Thrusday           39
# 3     Saturday           25
# 4     Thrusday           30
# ...        ...          ...
# 4995    Sunday           22
# 4996  Saturday           26
# 4997    Monday           23
# 4998    Sunday           30
# 4999   Tuesday           20
#
# [5000 rows x 2 columns]

# %%
df.head(7)
# Out:
#         Day  Temperature
# 0   Tuesday           21
# 1   Tuesday           26
# 2  Thrusday           39
# 3  Saturday           25
# 4  Thrusday           30
# 5    Monday           39
# 6    Friday           34

# %%
plt.plot(df['Day'], df['Temperature'], color='blue')
plt.title("Daily Temperature")
plt.xlabel("Day")
plt.ylabel("Temperature (°C)")
plt.grid()
plt.show()

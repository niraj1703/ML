# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\dhira\data.csv")
df.head()
# Out:
#    ID  Gender
# 0   1    Male
# 1   2     NaN
# 2   3  Female
# 3   4  Female
# 4   5    Male

# %%
df.shape
# Out:
# (5000, 2)

# %%
df.isnull()
# Out:
#          ID  Gender
# 0     False   False
# 1     False    True
# 2     False   False
# 3     False   False
# 4     False   False
# ...     ...     ...
# 4995  False   False
# 4996  False   False
# 4997  False   False
# 4998  False   False
# 4999  False   False
#
# [5000 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# ID          0
# Gender    479
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(479)

# %%
(df.isnull().sum().sum()/(df.shape[1]*df.shape[1]))*100
# Out:
# np.float64(11975.0)

# %%
df.isnull().values.any()
# Out:
# np.True_

# %%
(df.isnull().sum() / df.shape[0]) * 100
# Out:
# ID        0.00
# Gender    9.58
# dtype: float64

# %%
df.notnull().sum()
# Out:
# ID        5000
# Gender    4521
# dtype: int64

# %%
df.notnull().sum().sum
# Out:
# <bound method Series.sum of ID        5000
# Gender    4521
# dtype: int64>

# %%
sns.heatmap(df.notnull())
plt.show()

# %%
df[df.isnull().any(axis=1)]
# Out:
#         ID Gender
# 1        2    NaN
# 11      12    NaN
# 33      34    NaN
# 34      35    NaN
# 43      44    NaN
# ...    ...    ...
# 4945  4946    NaN
# 4966  4967    NaN
# 4968  4969    NaN
# 4980  4981    NaN
# 4990  4991    NaN
#
# [479 rows x 2 columns]

# %%
df.fillna(10).head()
# Out:
#    ID  Gender
# 0   1    Male
# 1   2      10
# 2   3  Female
# 3   4  Female
# 4   5    Male

# %%
df.fillna(method = "ffill")
# Out:
# C:\Users\dhira\AppData\Local\Temp\ipykernel_23544\3054842543.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = "ffill")
#         ID  Gender
# 0        1    Male
# 1        2    Male
# 2        3  Female
# 3        4  Female
# 4        5    Male
# ...    ...     ...
# 4995  4996   Other
# 4996  4997    Male
# 4997  4998    Male
# 4998  4999   Other
# 4999  5000  Female
#
# [5000 rows x 2 columns]

# %%
df.fillna(method = "bfill")
# Out:
# C:\Users\dhira\AppData\Local\Temp\ipykernel_23544\3988041702.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = "bfill")
#         ID  Gender
# 0        1    Male
# 1        2  Female
# 2        3  Female
# 3        4  Female
# 4        5    Male
# ...    ...     ...
# 4995  4996   Other
# 4996  4997    Male
# 4997  4998    Male
# 4998  4999   Other
# 4999  5000  Female
#
# [5000 rows x 2 columns]

# %%
df.fillna(method = "ffill",axis =0)
# Out:
# C:\Users\dhira\AppData\Local\Temp\ipykernel_23544\4262821096.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = "ffill",axis =0)
#         ID  Gender
# 0        1    Male
# 1        2    Male
# 2        3  Female
# 3        4  Female
# 4        5    Male
# ...    ...     ...
# 4995  4996   Other
# 4996  4997    Male
# 4997  4998    Male
# 4998  4999   Other
# 4999  5000  Female
#
# [5000 rows x 2 columns]

# %%
df.fillna(method = "bfill",axis =1)
# Out:
# C:\Users\dhira\AppData\Local\Temp\ipykernel_23544\183956270.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = "bfill",axis =1)
# C:\Users\dhira\AppData\Local\Temp\ipykernel_23544\183956270.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna(method = "bfill",axis =1)
#         ID  Gender
# 0        1    Male
# 1      2.0     NaN
# 2        3  Female
# 3        4  Female
# 4        5    Male
# ...    ...     ...
# 4995  4996   Other
# 4996  4997    Male
# 4997  4998    Male
# 4998  4999   Other
# 4999  5000  Female
#
# [5000 rows x 2 columns]

# %%
df
# Out:
#         ID  Gender
# 0        1    Male
# 1        2     NaN
# 2        3  Female
# 3        4  Female
# 4        5    Male
# ...    ...     ...
# 4995  4996   Other
# 4996  4997    Male
# 4997  4998    Male
# 4998  4999   Other
# 4999  5000  Female
#
# [5000 rows x 2 columns]

# %%
df['Age'] = np.random.randint(20, 40, size=len(df))
df['City'] = np.random.choice(['Delhi', 'Mumbai', 'Chennai', 'Kolkata'], size=len(df))
df['Score'] = np.random.randint(1, 40, size=len(df))
df['Country'] = np.random.choice(['India', 'USA', 'UK', 'Canada', 'India'], size=len(df))

# %%
df
# Out:
#         ID  Gender  Age     City  Score Country
# 0        1    Male   20  Kolkata     19     USA
# 1        2     NaN   33  Kolkata     20   India
# 2        3  Female   30   Mumbai     24      UK
# 3        4  Female   22   Mumbai     20   India
# 4        5    Male   20   Mumbai     35  Canada
# ...    ...     ...  ...      ...    ...     ...
# 4995  4996   Other   28   Mumbai      7  Canada
# 4996  4997    Male   29    Delhi     30  Canada
# 4997  4998    Male   38    Delhi     15   India
# 4998  4999   Other   38  Chennai     36   India
# 4999  5000  Female   20  Kolkata     31      UK
#
# [5000 rows x 6 columns]

# %%
df.dtypes
# Out:
# ID          int64
# Gender     object
# Age         int32
# City       object
# Score       int32
# Country    object
# dtype: object

# %%
df[df["Age"] > 30]
# Out:
#         ID  Gender  Age     City  Score Country
# 1        2     NaN   33  Kolkata     20   India
# 5        6    Male   31   Mumbai     18   India
# 7        8   Other   32  Chennai     29   India
# 9       10  Female   36    Delhi     25   India
# 16      17    Male   37   Mumbai     31     USA
# ...    ...     ...  ...      ...    ...     ...
# 4990  4991     NaN   32  Chennai     34  Canada
# 4991  4992  Female   38  Kolkata     27      UK
# 4994  4995    Male   33   Mumbai     31      UK
# 4997  4998    Male   38    Delhi     15   India
# 4998  4999   Other   38  Chennai     36   India
#
# [2249 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# ID           0
# Gender     479
# Age          0
# City         0
# Score        0
# Country      0
# dtype: int64

# %%
df["Gender"].fillna(df["Gender"].mode(), inplace=True)

# %%
df
# Out:
#         ID  Gender  Age     City  Score Country
# 0        1    Male   20  Kolkata     19     USA
# 1        2     NaN   33  Kolkata     20   India
# 2        3  Female   30   Mumbai     24      UK
# 3        4  Female   22   Mumbai     20   India
# 4        5    Male   20   Mumbai     35  Canada
# ...    ...     ...  ...      ...    ...     ...
# 4995  4996   Other   28   Mumbai      7  Canada
# 4996  4997    Male   29    Delhi     30  Canada
# 4997  4998    Male   38    Delhi     15   India
# 4998  4999   Other   38  Chennai     36   India
# 4999  5000  Female   20  Kolkata     31      UK
#
# [5000 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# ID           0
# Gender     479
# Age          0
# City         0
# Score        0
# Country      0
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       5000 non-null   int64
#  1   Gender   4521 non-null   object
#  2   Age      5000 non-null   int32
#  3   City     5000 non-null   object
#  4   Score    5000 non-null   int32
#  5   Country  5000 non-null   object
# dtypes: int32(2), int64(1), object(3)
# memory usage: 195.4+ KB

# %%
df.fillna("Other").head()
# Out:
#    ID  Gender  Age     City  Score Country
# 0   1    Male   20  Kolkata     19     USA
# 1   2   Other   33  Kolkata     20   India
# 2   3  Female   30   Mumbai     24      UK
# 3   4  Female   22   Mumbai     20   India
# 4   5    Male   20   Mumbai     35  Canada

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       5000 non-null   int64
#  1   Gender   4521 non-null   object
#  2   Age      5000 non-null   int32
#  3   City     5000 non-null   object
#  4   Score    5000 non-null   int32
#  5   Country  5000 non-null   object
# dtypes: int32(2), int64(1), object(3)
# memory usage: 195.4+ KB

# %%
df.isnull()
# Out:
#          ID  Gender    Age   City  Score  Country
# 0     False   False  False  False  False    False
# 1     False    True  False  False  False    False
# 2     False   False  False  False  False    False
# 3     False   False  False  False  False    False
# 4     False   False  False  False  False    False
# ...     ...     ...    ...    ...    ...      ...
# 4995  False   False  False  False  False    False
# 4996  False   False  False  False  False    False
# 4997  False   False  False  False  False    False
# 4998  False   False  False  False  False    False
# 4999  False   False  False  False  False    False
#
# [5000 rows x 6 columns]

# %%
df["City"] = df["City"].replace("Delhi", "New Delhi")

# %%
df
# Out:
#         ID  Gender  Age       City  Score Country
# 0        1    Male   20    Kolkata     19     USA
# 1        2     NaN   33    Kolkata     20   India
# 2        3  Female   30     Mumbai     24      UK
# 3        4  Female   22     Mumbai     20   India
# 4        5    Male   20     Mumbai     35  Canada
# ...    ...     ...  ...        ...    ...     ...
# 4995  4996   Other   28     Mumbai      7  Canada
# 4996  4997    Male   29  New Delhi     30  Canada
# 4997  4998    Male   38  New Delhi     15   India
# 4998  4999   Other   38    Chennai     36   India
# 4999  5000  Female   20    Kolkata     31      UK
#
# [5000 rows x 6 columns]

# %%
df.rename(columns={"City": "Cites"}, inplace=True)

# %%
df
# Out:
#         ID  Gender  Age     Cities  Score Country
# 0        1    Male   20    Kolkata     19     USA
# 1        2     NaN   33    Kolkata     20   India
# 2        3  Female   30     Mumbai     24      UK
# 3        4  Female   22     Mumbai     20   India
# 4        5    Male   20     Mumbai     35  Canada
# ...    ...     ...  ...        ...    ...     ...
# 4995  4996   Other   28     Mumbai      7  Canada
# 4996  4997    Male   29  New Delhi     30  Canada
# 4997  4998    Male   38  New Delhi     15   India
# 4998  4999   Other   38    Chennai     36   India
# 4999  5000  Female   20    Kolkata     31      UK
#
# [5000 rows x 6 columns]

# %%
df.rename(columns={"Cites": "Cities"}, inplace=True)

# %%
df
# Out:
#         ID  Gender  Age     Cities  Score Country
# 0        1    Male   20    Kolkata     19     USA
# 1        2     NaN   33    Kolkata     20   India
# 2        3  Female   30     Mumbai     24      UK
# 3        4  Female   22     Mumbai     20   India
# 4        5    Male   20     Mumbai     35  Canada
# ...    ...     ...  ...        ...    ...     ...
# 4995  4996   Other   28     Mumbai      7  Canada
# 4996  4997    Male   29  New Delhi     30  Canada
# 4997  4998    Male   38  New Delhi     15   India
# 4998  4999   Other   38    Chennai     36   India
# 4999  5000  Female   20    Kolkata     31      UK
#
# [5000 rows x 6 columns]

# %%
df.sort_values(by="Age", ascending=True)
# Out:
#         ID  Gender  Age     Cities  Score Country
# 0        1    Male   20    Kolkata     19     USA
# 4999  5000  Female   20    Kolkata     31      UK
# 2999  3000   Other   20     Mumbai     29      UK
# 3024  3025    Male   20  New Delhi      9  Canada
# 3029  3030  Female   20     Mumbai      4   India
# ...    ...     ...  ...        ...    ...     ...
# 4037  4038  Female   39     Mumbai     38   India
# 3997  3998    Male   39     Mumbai     19   India
# 1516  1517  Female   39     Mumbai     10      UK
# 4975  4976  Female   39    Kolkata     32  Canada
# 4973  4974  Female   39  New Delhi     23   India
#
# [5000 rows x 6 columns]

# %%
df.query("Age >= 25 and Age <= 35")
# Out:
#         ID  Gender  Age     Cities  Score Country
# 1        2     NaN   33    Kolkata     20   India
# 2        3  Female   30     Mumbai     24      UK
# 5        6    Male   31     Mumbai     18   India
# 6        7    Male   28     Mumbai     14     USA
# 7        8   Other   32    Chennai     29   India
# ...    ...     ...  ...        ...    ...     ...
# 4990  4991     NaN   32    Chennai     34  Canada
# 4993  4994  Female   26     Mumbai     20      UK
# 4994  4995    Male   33     Mumbai     31      UK
# 4995  4996   Other   28     Mumbai      7  Canada
# 4996  4997    Male   29  New Delhi     30  Canada
#
# [2811 rows x 6 columns]

# %%
df[df["Age"].between(25, 35)]
# Out:
#         ID  Gender  Age     Cities  Score Country
# 1        2     NaN   33    Kolkata     20   India
# 2        3  Female   30     Mumbai     24      UK
# 5        6    Male   31     Mumbai     18   India
# 6        7    Male   28     Mumbai     14     USA
# 7        8   Other   32    Chennai     29   India
# ...    ...     ...  ...        ...    ...     ...
# 4990  4991     NaN   32    Chennai     34  Canada
# 4993  4994  Female   26     Mumbai     20      UK
# 4994  4995    Male   33     Mumbai     31      UK
# 4995  4996   Other   28     Mumbai      7  Canada
# 4996  4997    Male   29  New Delhi     30  Canada
#
# [2811 rows x 6 columns]

# %%
df.to_excel('output.xlsx', index=True)

# %%
df
# Out:
#         ID  Gender  Age     Cities  Score Country
# 0        1    Male   20    Kolkata     19     USA
# 1        2     NaN   33    Kolkata     20   India
# 2        3  Female   30     Mumbai     24      UK
# 3        4  Female   22     Mumbai     20   India
# 4        5    Male   20     Mumbai     35  Canada
# ...    ...     ...  ...        ...    ...     ...
# 4995  4996   Other   28     Mumbai      7  Canada
# 4996  4997    Male   29  New Delhi     30  Canada
# 4997  4998    Male   38  New Delhi     15   India
# 4998  4999   Other   38    Chennai     36   India
# 4999  5000  Female   20    Kolkata     31      UK
#
# [5000 rows x 6 columns]

# %%
df.to_excel('output.xlsx', index=True)

# %%
df
# Out:
#         ID  Gender  Age     Cities  Score Country
# 0        1    Male   20    Kolkata     19     USA
# 1        2     NaN   33    Kolkata     20   India
# 2        3  Female   30     Mumbai     24      UK
# 3        4  Female   22     Mumbai     20   India
# 4        5    Male   20     Mumbai     35  Canada
# ...    ...     ...  ...        ...    ...     ...
# 4995  4996   Other   28     Mumbai      7  Canada
# 4996  4997    Male   29  New Delhi     30  Canada
# 4997  4998    Male   38  New Delhi     15   India
# 4998  4999   Other   38    Chennai     36   India
# 4999  5000  Female   20    Kolkata     31      UK
#
# [5000 rows x 6 columns]

# %%
df.describe()
# Out:
#                 ID          Age        Score
# count  5000.000000  5000.000000  5000.000000
# mean   2500.500000    29.519000    19.958800
# std    1443.520003     5.736987    11.072706
# min       1.000000    20.000000     1.000000
# 25%    1250.750000    25.000000    10.000000
# 50%    2500.500000    29.000000    20.000000
# 75%    3750.250000    34.000000    29.000000
# max    5000.000000    39.000000    39.000000

# %%
df.loc[0]
# Out:
# ID               1
# Gender        Male
# Age             20
# Cities     Kolkata
# Score           19
# Country        USA
# Name: 0, dtype: object

# %%
df.shape
# Out:
# (5000, 6)

# %%
df
# Out:
#         ID  Gender  Age     Cities  Score Country
# 0        1    Male   20    Kolkata     19     USA
# 1        2     NaN   33    Kolkata     20   India
# 2        3  Female   30     Mumbai     24      UK
# 3        4  Female   22     Mumbai     20   India
# 4        5    Male   20     Mumbai     35  Canada
# ...    ...     ...  ...        ...    ...     ...
# 4995  4996   Other   28     Mumbai      7  Canada
# 4996  4997    Male   29  New Delhi     30  Canada
# 4997  4998    Male   38  New Delhi     15   India
# 4998  4999   Other   38    Chennai     36   India
# 4999  5000  Female   20    Kolkata     31      UK
#
# [5000 rows x 6 columns]

# %%
df.iloc[0]
# Out:
# ID               1
# Gender        Male
# Age             20
# Cities     Kolkata
# Score           19
# Country        USA
# Name: 0, dtype: object

# %%
df['Age'] = df['Age'] + 1

# %%
df
# Out:
#         ID  Gender  Age     Cities  Score Country
# 0        1    Male   21    Kolkata     19     USA
# 1        2     NaN   34    Kolkata     20   India
# 2        3  Female   31     Mumbai     24      UK
# 3        4  Female   23     Mumbai     20   India
# 4        5    Male   21     Mumbai     35  Canada
# ...    ...     ...  ...        ...    ...     ...
# 4995  4996   Other   29     Mumbai      7  Canada
# 4996  4997    Male   30  New Delhi     30  Canada
# 4997  4998    Male   39  New Delhi     15   India
# 4998  4999   Other   39    Chennai     36   India
# 4999  5000  Female   21    Kolkata     31      UK
#
# [5000 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       5000 non-null   int64
#  1   Gender   4521 non-null   object
#  2   Age      5000 non-null   int32
#  3   Cities   5000 non-null   object
#  4   Score    5000 non-null   int32
#  5   Country  5000 non-null   object
# dtypes: int32(2), int64(1), object(3)
# memory usage: 195.4+ KB

# %%
df.dropna()
# Out:
#         ID  Gender  Age     Cities  Score Country
# 0        1    Male   21    Kolkata     19     USA
# 2        3  Female   31     Mumbai     24      UK
# 3        4  Female   23     Mumbai     20   India
# 4        5    Male   21     Mumbai     35  Canada
# 5        6    Male   32     Mumbai     18   India
# ...    ...     ...  ...        ...    ...     ...
# 4995  4996   Other   29     Mumbai      7  Canada
# 4996  4997    Male   30  New Delhi     30  Canada
# 4997  4998    Male   39  New Delhi     15   India
# 4998  4999   Other   39    Chennai     36   India
# 4999  5000  Female   21    Kolkata     31      UK
#
# [4521 rows x 6 columns]
